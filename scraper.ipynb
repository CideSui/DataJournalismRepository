# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

url = 'http://www.president.gov.ua/news/speeches'
response = urlopen(url)
html = response.read()


selector = 'h3'
soup = BeautifulSoup(html, "html.parser")
bills = soup.select(selector)

for l in bills:
    	if re.match(u".*", l.text): print(l.text)
# Out:
# Виступ Президента на церемонії вшанування пам’яті жертв політичних репресій у Національному історико-меморіальному заповіднику «Биківнянські могили»
#
#
# Виступ Президента України на урочистостях із нагоди 50-річчя служіння на Київській кафедрі Святійшого Патріарха Філарета
#
#
# Слово Президента під час молитви капеланів–учасників АТО за мир та перемогу
#
#
# Виступ Президента під час акції «Перша хвилина миру» у День пам’яті та примирення
#
#
# Виступ Президента на відкритті фотовиставки «Матері героїв»
#
#
# Звернення Президента України з нагоди Дня матері
#
#
# Виступ Президента під час заходів у зв'язку з 30-ми роковинами Чорнобильської катастрофи
#
#
# Звернення Президента України з нагоди Міжнародного дня визволення в’язнів нацистських таборів
#
#
# Звернення Президента до Верховного архієпископа Києво-Галицького Української Греко-Католицької церкви Святослава Шевчука, єпископів, священнослужителів та вірних Української Греко-Католицької Церкви
#
#
# Виступ Президента на церемонії вручення Національної  премії України ім.Тараса Шевченка
#
# Новини
# Фото
# Відео
# Документи
# Президент
# Адміністрація
# Прес-центр
# Звернення громадян
# Публічна інформація
# Очищення влади
